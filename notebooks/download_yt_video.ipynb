# %%
! pip install pytubefix
# Out:
# ...
#   Using cached pytubefix-10.2.1-py3-none-any.whl.metadata (9.2 kB)
# ...
#   Using cached aiohttp-3.13.2-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# ...
#   Using cached nodejs_wheel_binaries-22.20.0-py2.py3-none-win_amd64.whl.metadata (4.6 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# ...
#   Using cached multidict-6.7.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# ...
# Using cached pytubefix-10.2.1-py3-none-any.whl (1.5 MB)
# Using cached aiohttp-3.13.2-cp312-cp312-win_amd64.whl (453 kB)
# Using cached nodejs_wheel_binaries-22.20.0-py2.py3-none-win_amd64.whl (40.1 MB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# ...

# %%
#Code to download the youtube video

from pytubefix import YouTube

# %%
video_path="https://youtu.be/j8R2cl8xA70?si=xDA-wICO90L1mWpH"

yt = YouTube(video_path)
stream = yt.streams.filter(file_extension='mp4', res='1080p').first()
stream.download(filename="IND-vs-AUS.mp4")
# Out:
# 'c:\\Users\\infan\\OneDrive\\Desktop\\Final Project- Jio_AdVision_Analytics\\Jio_AdVision_Analytics\\notebooks\\IND-vs-AUS.mp4'
